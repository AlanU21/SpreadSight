# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('CLEANED_CDX.csv')

# %%
new_df=df[~df.isnull().any(axis=1)]

# %%
new_df=df[df['Date']>'08-08-2012']

# %%
new_df['Date']=pd.to_datetime(new_df['Date'])

# %%
new_df.set_index('Date',inplace=True)

# %%
print(new_df.index)
# Out:
# DatetimeIndex(['2024-02-16', '2024-02-15', '2024-02-14', '2024-02-13',
#                '2024-02-12', '2024-02-09', '2024-02-08', '2024-02-07',
#                '2024-02-06', '2024-02-05',
#                ...
#                '2012-08-22', '2012-08-21', '2012-08-20', '2012-08-17',
#                '2012-08-16', '2012-08-15', '2012-08-14', '2012-08-13',
#                '2012-08-10', '2012-08-09'],
#               dtype='datetime64[ns]', name='Date', length=2877, freq=None)

# %%
weeks = new_df.resample('W').mean()

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(new_df.index, new_df['CDX IG Spread'], label='Original')

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(new_df.index, new_df['CDX HY Spread'], label='Original')

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(new_df.index, new_df['SPX Index '], label='Original')

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(new_df.index, new_df['VIX Index  (L1)'], label='Original')

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(new_df.index, new_df['Freddie Mac 30 Year Mortgage Rate'], label='Original')
