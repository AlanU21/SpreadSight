# %%
import pandas as pd

df = pd.read_excel('CreditDefaultIndices.xlsx')

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_4fff3_row0_col0, #T_4fff3_row1_col1, #T_4fff3_row2_col2, #T_4fff3_row3_col3, #T_4fff3_row4_col4, #T_4fff3_row5_col5, #T_4fff3_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4fff3_row0_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_4fff3_row0_col2, #T_4fff3_row4_col5 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_4fff3_row0_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_4fff3_row0_col4 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_4fff3_row0_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_4fff3_row0_col6 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_4fff3_row1_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_4fff3_row1_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_4fff3_row1_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_4fff3_row1_col4 {
#   background-color: #6fa7ce;
# ...
